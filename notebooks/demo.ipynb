# %%
# Add relevant Jupyter notebook extensions

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['C:\\Users\\tommy\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'C:\\Users\\tommy\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'C:\\Users\\tommy\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'C:\\Users\\tommy\\AppData\\Local\\Programs\\Python\\Python312', 'c:\\Users\\tommy\\b1-coding-practical-mt24\\venv312', '', 'c:\\Users\\tommy\\b1-coding-practical-mt24\\venv312\\Lib\\site-packages', 'c:\\Users\\tommy\\b1-coding-practical-mt24', 'c:\\Users\\tommy\\b1-coding-practical-mt24']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from uuv_mission.dynamic import Mission, Submarine, ClosedLoop
from control import PDController
import numpy as np


sub = Submarine()
# Instantiate your controller (depending on your implementation)
controller = PDController(Kp=0.1, Kd=0.81)
closed_loop = ClosedLoop(sub, controller)
mission = Mission.from_csv("../data/mission.csv") # You must implement this method in the Mission class

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
